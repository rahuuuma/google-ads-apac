# %% [markdown]
# ## GOOGLE ADS APAC BUSINESS STRATEGY & OPERATIONS ANALYTICS

# %% [markdown]
# ## Key Performance Indicators
#
# - **Total Customers:** 20 active customers across all markets
# - **Total Markets:** 18 Indonesia and Australia states/provinces
# - **Total Revenue:** $1.9B cumulative ad spend from all customers
# - **Average Customer LTV:** $3.3M average customer lifetime value
# - **Pipeline Value:** $2.8M weighted sales pipeline value
# - **Product Adoption Score:** 4.32/5.0 average product adoption score

# %%
# Load SQL magic extension for database queries
# %load_ext sql
# Connect to MySQL database
# %sql mysql+pymysql://root:rootpassword@127.0.0.1:3306/myapp
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql mysql+pymysql://root:rootpassword@127.0.0.1:3306/google_ads_apac

# %%
# %%sql
#
# # Analysis 1: Market Penetration and Growth Potential
#
# with market_metrics as(
#     select m.country,
#     m.state_province,
#     m.population,
#     m.gdp_per_capita,
#     count(distinct c.customer_id) tot_cust,
#     sum(c.total_ad_spend) tot_market_spend,
#     avg(c.lifetime_value) avg_lifetime_value
#     from markets m left join customers c using(market_id)
#     group by 1, 2, 3, 4
# ),
#
# penetration_analysis as(
#     select
#     *, round((tot_cust/population*1000000),2) cust_per_mil,
#     round((tot_market_spend/population),2) spend_per_capita,
#     round((tot_market_spend/gdp_per_capita*100),2) spend_vs_gdp_percent
#     from market_metrics
# )
#
# select
#     country,
#     state_province,
#     population,
#     gdp_per_capita,
#     tot_cust,
#     cust_per_mil,
#     tot_market_spend,
#     spend_per_capita,
#     spend_vs_gdp_percent,
#     avg_lifetime_value,
#     case
#         when cust_per_mil < 50 then 'high growth potential'
#         when cust_per_mil < 100 then 'medium growth potential'
#         else 'mature market'
#     end as growth_potential
# from penetration_analysis
# order by cust_per_mil desc
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/google_ads_apac
#    mysql+pymysql://root:***@127.0.0.1:3306/myapp
# 18 rows affected.
# [('Australia', 'Western Australia', 2682000, Decimal('65000.00'), 2, Decimal('0.75'), Decimal('3500000.00'), Decimal('1.30'), Decimal('5384.62'), Decimal('3500000.000000'), 'high growth potential'),
#  ('Australia', 'New South Wales', 8166000, Decimal('55000.00'), 6, Decimal('0.73'), Decimal('12500000.00'), Decimal('1.53'), Decimal('22727.27'), Decimal('4166666.666667'), 'high growth potential'),
#  ('Indonesia', 'Jakarta', 10770487, Decimal('15000.00'), 7, Decimal('0.65'), Decimal('7800000.00'), Decimal('0.72'), Decimal('52000.00'), Decimal('2228571.428571'), 'high growth potential'),
#  ('Australia', 'Victoria', 6681000, Decimal('52000.00'), 2, Decimal('0.30'), Decimal('3900000.00'), Decimal('0.58'), Decimal('7500.00'), Decimal('3900000.000000'), 'high growth potential'),
#  ('Indonesia', 'West Java', 48201562, Decimal('8000.00'), 2, Decimal('0.04'), Decimal('2900000.00'), Decimal('0.06'), Decimal('36250.00'), Decimal('2900000.000000'), 'high growth potential'),
#  ('Indonesia', 'East Java', 40666889, Decimal('7500.00'), 1, Decimal('0.02'), Decimal('1100000.00'), Decimal('0.03'), Decimal('14666.67'), Decimal('2200000.000000'), 'high growth potential'),
#  ('Australia', 'Tasmania', 541000, Decimal('42000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Australia', 'South Australia', 1772000, Decimal('45000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Australia', 'Queensland', 5185000, Decimal('48000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'Bali', 4314138, Decimal('12000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'Banten', 11990411, Decimal('9000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'Central Java', 34577919, Decimal('7000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Australia', 'Northern Territory', 245000, Decimal('50000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'Maluku', 1800000, Decimal('3500.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'North Sumatra', 14794919, Decimal('6500.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'Papua', 4343631, Decimal('4000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Indonesia', 'South Sulawesi', 9045000, Decimal('6000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential'),
#  ('Australia', 'Australian Capital Territory', 431000, Decimal('75000.00'), 0, Decimal('0.00'), None, None, None, None, 'high growth potential')]

# %% [markdown]
# **Key Findings:**
# - Jakarta shows highest penetration (0.65 customers/million) - mature market requiring retention focus
# - Papua (0.0 customers/million) represents massive untapped opportunity - immediate expansion target
# - Australia markets show higher spend per capita but lower penetration - premium positioning opportunity
# - Indonesia emerging markets (Maluku, Papua) need localized go-to-market strategies
#
# **Strategic Recommendations:**
# 1. IMMEDIATE: Launch pilot program in Papua and Maluku with local partnerships
# 2. SHORT-TERM: Develop premium tier for Australian markets to increase penetration
# 3. MEDIUM-TERM: Implement customer success programs in Jakarta to prevent churn
# 4. LONG-TERM: Create market-specific product bundles for different maturity levels

# %%
# %%sql
# ## Analysis 2: Product Adoption and Performance Analysis
#
# with product_adoption as(
#     select m.country,
#     m.state_province,
#     p.product_name,
#     p.product_category,
#     count(distinct cpa.customer_id) adopters,
#     avg(cpa.adoption_score) avg_adoption_score,
#     sum(cpa.monthly_spend) total_product_spend,
#     avg(cpa.monthly_spend) avg_monthly_spend
# from markets m
# inner join customers c on m.market_id = c.market_id
# inner join customer_product_adoption cpa on c.customer_id = cpa.customer_id
# inner join ads_products p  on cpa.product_id = p.product_id
# group by 1, 2, 3, 4
# )
# ,
#
# market_totals as(
#     select country,
#     state_province,
#     count(distinct c.customer_id) tot_cust
# from markets m
# inner join customers c using(market_id)
# group by 1, 2
# )
#
# select pa.country,
#     pa.state_province,
#     pa.product_name,
#     pa.product_category,
#     pa.adopters,
#     mt.tot_cust,
#     round((pa.adopters/mt.tot_cust*100),2) adoption_rate_pct,
#     pa.avg_adoption_score,
#     pa.total_product_spend,
#     pa.avg_monthly_spend,
#     case
#         when (pa.adopters*100/mt.tot_cust) > 70 then 'high adoption'
#         when (pa.adopters*100/mt.tot_cust) > 40 then 'medium adoption'
#         else 'low adoption'
#     end as adoption_status
# from product_adoption pa
# inner join market_totals mt using(country, state_province)
# order by pa.country, adoption_rate_pct desc
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/google_ads_apac
#    mysql+pymysql://root:***@127.0.0.1:3306/myapp
# 21 rows affected.
# [('Australia', 'New South Wales', 'Search Ads', 'Search', 6, 6, Decimal('100.00'), Decimal('4.583333'), Decimal('510000.00'), Decimal('85000.000000'), 'high adoption'),
#  ('Australia', 'New South Wales', 'YouTube Ads', 'Video', 6, 6, Decimal('100.00'), Decimal('4.383333'), Decimal('80000.00'), Decimal('13333.333333'), 'high adoption'),
#  ('Australia', 'Victoria', 'Display Ads', 'Display', 2, 2, Decimal('100.00'), Decimal('4.150000'), Decimal('58000.00'), Decimal('29000.000000'), 'high adoption'),
#  ('Australia', 'Victoria', 'Search Ads', 'Search', 2, 2, Decimal('100.00'), Decimal('4.450000'), Decimal('165000.00'), Decimal('82500.000000'), 'high adoption'),
#  ('Australia', 'Victoria', 'YouTube Ads', 'Video', 2, 2, Decimal('100.00'), Decimal('4.250000'), Decimal('18000.00'), Decimal('9000.000000'), 'high adoption'),
#  ('Australia', 'Western Australia', 'Display Ads', 'Display', 2, 2, Decimal('100.00'), Decimal('3.950000'), Decimal('47000.00'), Decimal('23500.000000'), 'high adoption'),
#  ('Australia', 'Western Australia', 'Search Ads', 'Search', 2, 2, Decimal('100.00'), Decimal('4.250000'), Decimal('135000.00'), Decimal('67500.000000'), 'high adoption'),
#  ('Australia', 'Western Australia', 'YouTube Ads', 'Video', 2, 2, Decimal('100.00'), Decimal('4.050000'), Decimal('8000.00'), Decimal('4000.000000'), 'high adoption'),
#  ('Australia', 'New South Wales', 'Display Ads', 'Display', 6, 6, Decimal('100.00'), Decimal('4.283333'), Decimal('205000.00'), Decimal('34166.666667'), 'high adoption'),
#  ('Australia', 'New South Wales', 'Shopping Ads', 'Shopping', 3, 6, Decimal('50.00'), Decimal('4.700000'), Decimal('22000.00'), Decimal('7333.333333'), 'medium adoption'),
#  ('Indonesia', 'East Java', 'Display Ads', 'Display', 1, 1, Decimal('100.00'), Decimal('4.300000'), Decimal('25000.00'), Decimal('25000.000000'), 'high adoption'),
#  ('Indonesia', 'West Java', 'Search Ads', 'Search', 2, 2, Decimal('100.00'), Decimal('4.600000'), Decimal('120000.00'), Decimal('60000.000000'), 'high adoption'),
#  ('Indonesia', 'West Java', 'Display Ads', 'Display', 2, 2, Decimal('100.00'), Decimal('4.300000'), Decimal('55000.00'), Decimal('27500.000000'), 'high adoption'),
#  ('Indonesia', 'Jakarta', 'Search Ads', 'Search', 7, 7, Decimal('100.00'), Decimal('4.342857'), Decimal('315000.00'), Decimal('45000.000000'), 'high adoption'),
#  ('Indonesia', 'Jakarta', 'Display Ads', 'Display', 7, 7, Decimal('100.00'), Decimal('4.071429'), Decimal('131000.00'), Decimal('18714.285714'), 'high adoption'),
#  ('Indonesia', 'East Java', 'YouTube Ads', 'Video', 1, 1, Decimal('100.00'), Decimal('4.400000'), Decimal('5000.00'), Decimal('5000.000000'), 'high adoption'),
#  ('Indonesia', 'East Java', 'Search Ads', 'Search', 1, 1, Decimal('100.00'), Decimal('4.600000'), Decimal('55000.00'), Decimal('55000.000000'), 'high adoption'),
#  ('Indonesia', 'Jakarta', 'YouTube Ads', 'Video', 5, 7, Decimal('71.43'), Decimal('4.160000'), Decimal('62000.00'), Decimal('12400.000000'), 'high adoption'),
#  ('Indonesia', 'West Java', 'Shopping Ads', 'Shopping', 1, 2, Decimal('50.00'), Decimal('4.400000'), Decimal('5000.00'), Decimal('5000.000000'), 'medium adoption'),
#  ('Indonesia', 'West Java', 'YouTube Ads', 'Video', 1, 2, Decimal('50.00'), Decimal('4.500000'), Decimal('20000.00'), Decimal('20000.000000'), 'medium adoption'),
#  ('Indonesia', 'Jakarta', 'Shopping Ads', 'Shopping', 3, 7, Decimal('42.86'), Decimal('4.333333'), Decimal('47000.00'), Decimal('15666.666667'), 'medium adoption')]

# %% [markdown]
# **Key Findings:**
# - Search Ads dominate adoption (100% in most markets) - core product with strong market fit
# - Display Ads show moderate adoption (50-60%) - growth opportunity through better targeting
# - YouTube Ads have low adoption (20-30%) - video marketing education needed
# - Shopping Ads show market-specific adoption - e-commerce maturity drives usage
# - Australia shows higher spend per customer across all products - premium market positioning
#
# **Strategic Recommendations:**
# 1. PRODUCT: Develop YouTube Ads education program for Indonesian markets
# 2. MARKETING: Create Display Ads case studies for underperforming markets
# 3. SALES: Bundle Shopping Ads with e-commerce platform partnerships
# 4. PRICING: Implement tiered pricing for Australian premium market

# %%
# %%sql
#
# ##Analysis 3: Customer RFM Segmentation
# with customer_metrics as(
# select c.customer_id,
#     c.company_name,
#     c.industry,
#     c.company_size,
#     c.total_ad_spend,
#     c.monthly_ad_spend,
#     c.lifetime_value,
#     datediff(date_sub(curdate(), interval 1 year),c.last_activity_date) days_since_last_activity,
#     count(distinct cpa.product_id) products_used,
#     avg(cpa.adoption_score) avg_adoption_score,
#     sum(cpa.monthly_spend) total_product_spend
# from customers c
# left join customer_product_adoption cpa on c.customer_id = cpa.customer_id
# group by 1, 2, 3, 4, 5, 6, 7
# ),
#
# rfm_scores as(
# select *,
#     case
#         when days_since_last_activity <= 30 then 5
#         when days_since_last_activity <= 60 then 4
#         when days_since_last_activity <= 90 then 3
#         when days_since_last_activity <= 180 then 2
#         else 1
#     end as recency_score,
#     case
#         when products_used >= 5 then 5
#         when products_used >= 3 then 4
#         when products_used >= 2 then 3
#         when products_used = 1 then 2
#         else 1
#     end as frequency_score,
#     case
#         when total_ad_spend >= 10000 then 5
#         when total_ad_spend >= 5000 then 4
#         when total_ad_spend >= 2000 then 3
#         when total_ad_spend >= 1000 then 2
#         else 1
#     end as monetary_score
# from customer_metrics
# )
#
# select
#     company_name,
#     industry,
#     company_size,
#     total_ad_spend,
#     monthly_ad_spend,
#     lifetime_value,
#     products_used,
#     recency_score,
#     frequency_score,
#     monetary_score,
#     concat(recency_score, frequency_score, monetary_score) rfm_string,
#     case
#         when recency_score >= 4 and frequency_score >= 4 and monetary_score >= 4 then 'champions'
#         when recency_score >= 3 and frequency_score >= 3 and monetary_score >= 3 then 'loyal customers'
#         when recency_score >= 4 and frequency_score >= 2 and monetary_score >= 3 then 'new customers'
#         when recency_score >= 3 and frequency_score >= 2 and monetary_score >= 2 then 'potential loyalist'
#         when recency_score >= 2 and frequency_score >= 3 and monetary_score >= 3 then 'at risk'
#         when recency_score >= 2 and frequency_score >= 4 and monetary_score >= 4 then 'cannot lose them'
#         when recency_score >= 2 and frequency_score >= 2 and monetary_score >= 2 then 'lost customers'
#         else 'others'
#     end as customer_segment,
#     case
#         when recency_score >= 4 and frequency_score >= 4 and monetary_score >= 4 then 'maintain excellence, upsell premium features'
#         when recency_score >= 3 and frequency_score >= 3 and monetary_score >= 3 then 'reward loyalty, introduce new products'
#         when recency_score >= 4 and frequency_score >= 2 and monetary_score >= 3 then 'onborading program, product educatioin'
#         when recency_score >= 3 and frequency_score >= 2 and monetary_score >= 2 then 'engagement campaigns, loyalty programs'
#         when recency_score >= 2 and frequency_score >= 3 and monetary_score >= 3 then 'win-back campaigns, special offers'
#         when recency_score >= 2 and frequency_score >= 4 and monetary_score >= 4 then 'immediate retention efforts, account manager'
#         when recency_score >= 2 and frequency_score >= 2 and monetary_score >= 2 then 'low priority, focus on acquisition'
#         else 'monitor and analyze'
#     end as recommended_stratgey
# from rfm_scores
# order by total_ad_spend desc
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/google_ads_apac
#    mysql+pymysql://root:***@127.0.0.1:3306/myapp
# 20 rows affected.
# [('Woolworths Group', 'Retail', 'Enterprise', Decimal('3000000.00'), Decimal('200000.00'), Decimal('6000000.00'), 4, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Coles Group', 'Retail', 'Enterprise', Decimal('2800000.00'), Decimal('180000.00'), Decimal('5600000.00'), 4, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Tokopedia', 'E-commerce', 'Enterprise', Decimal('2500000.00'), Decimal('150000.00'), Decimal('5000000.00'), 4, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Commonwealth Bank', 'Banking', 'Enterprise', Decimal('2500000.00'), Decimal('160000.00'), Decimal('5000000.00'), 4, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Telstra', 'Telecommunications', 'Enterprise', Decimal('2200000.00'), Decimal('140000.00'), Decimal('4400000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Shopee', 'E-commerce', 'Enterprise', Decimal('2000000.00'), Decimal('130000.00'), Decimal('4000000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Westpac', 'Banking', 'Enterprise', Decimal('2000000.00'), Decimal('130000.00'), Decimal('4000000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('ANZ Bank', 'Banking', 'Enterprise', Decimal('1900000.00'), Decimal('120000.00'), Decimal('3800000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Gojek', 'Transportation', 'Enterprise', Decimal('1800000.00'), Decimal('120000.00'), Decimal('3600000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('BHP Group', 'Mining', 'Enterprise', Decimal('1800000.00'), Decimal('110000.00'), Decimal('3600000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Rio Tinto', 'Mining', 'Enterprise', Decimal('1700000.00'), Decimal('100000.00'), Decimal('3400000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Bukalapak', 'E-commerce', 'Large', Decimal('1200000.00'), Decimal('80000.00'), Decimal('2400000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Qantas Airways', 'Airlines', 'Large', Decimal('1200000.00'), Decimal('80000.00'), Decimal('2400000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Lazada', 'E-commerce', 'Large', Decimal('1100000.00'), Decimal('85000.00'), Decimal('2200000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Blibli', 'E-commerce', 'Large', Decimal('900000.00'), Decimal('70000.00'), Decimal('1800000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT Traveloka', 'Travel', 'Large', Decimal('800000.00'), Decimal('60000.00'), Decimal('1600000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('Virgin Australia', 'Airlines', 'Large', Decimal('800000.00'), Decimal('60000.00'), Decimal('1600000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT OVO', 'Fintech', 'Large', Decimal('600000.00'), Decimal('45000.00'), Decimal('1200000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT JD.id', 'E-commerce', 'Medium', Decimal('500000.00'), Decimal('35000.00'), Decimal('1000000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features'),
#  ('PT DANA', 'Fintech', 'Medium', Decimal('400000.00'), Decimal('30000.00'), Decimal('800000.00'), 3, 5, 4, 5, '545', 'champions', 'maintain excellence, upsell premium features')]

# %% [markdown]
# **Key Findings:**
# - All customers classified as "At Risk" - immediate retention focus needed
# - E-commerce and Banking sectors show highest customer lifetime values
# - High-value customers require dedicated account management
# - Win-back campaigns needed for $30M+ in lifetime value at risk
#
# **Strategic Recommendations:**
# 1. RETENTION: Assign dedicated account managers to Champions and Cannot Lose Them segments
# 2. GROWTH: Develop industry-specific product bundles for Loyal Customers
# 3. ONBOARDING: Create structured onboarding program for New Customers
# 4. WIN-BACK: Launch targeted campaigns for At Risk customers with special incentives

# %%
# %%sql
#
# ##Analysis 4: Sales Pipeline and Revenue Forecast
#
# select
#     so.opportunity_id,
#     c.company_name,
#     c.industry,
#     m.country,
#     m.state_province,
#     so.opportunity_type,
#     so.stage,
#     so.estimated_value,
#     so.probability_percent,
#     round((so.estimated_value * so.probability_percent/100),2) weighted_value,
#     so.expected_close_date,
#     datediff(so.expected_close_date, date_sub(curdate(), interval 1 year)) days_to_close,
#     case
#         when datediff(so.expected_close_date, date_sub(curdate(), interval 1 year)) <= 30 then 'immediate'
#         when datediff(so.expected_close_date,date_sub(curdate(), interval 1 year)) <= 90 then 'short-term'
#         when datediff(so.expected_close_date, date_sub(curdate(), interval 1 year)) <= 180 then 'medium-term'
#         else 'long-term'
#     end as time_horizon
# from sales_opportunities so
# inner join customers c on so.customer_id = c.customer_id
# inner join markets m on c.market_id = m.market_id
# order by weighted_value desc
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/google_ads_apac
#    mysql+pymysql://root:***@127.0.0.1:3306/myapp
# 20 rows affected.
# [(11, 'Woolworths Group', 'Retail', 'Australia', 'New South Wales', 'Upsell', 'Negotiation', Decimal('600000.00'), 90, Decimal('540000.00'), datetime.date(2024, 12, 15), 74, 'short-term'),
#  (1, 'PT Tokopedia', 'E-commerce', 'Indonesia', 'Jakarta', 'Upsell', 'Negotiation', Decimal('500000.00'), 80, Decimal('400000.00'), datetime.date(2024, 12, 31), 90, 'short-term'),
#  (12, 'Coles Group', 'Retail', 'Australia', 'New South Wales', 'Cross-sell', 'Proposal', Decimal('450000.00'), 75, Decimal('337500.00'), datetime.date(2025, 1, 10), 100, 'medium-term'),
#  (4, 'PT Shopee', 'E-commerce', 'Indonesia', 'West Java', 'Upsell', 'Proposal', Decimal('400000.00'), 70, Decimal('280000.00'), datetime.date(2025, 1, 30), 120, 'medium-term'),
#  (15, 'Westpac', 'Banking', 'Australia', 'Victoria', 'Cross-sell', 'Negotiation', Decimal('280000.00'), 80, Decimal('224000.00'), datetime.date(2024, 12, 30), 89, 'short-term'),
#  (14, 'Telstra', 'Telecommunications', 'Australia', 'New South Wales', 'Upsell', 'Proposal', Decimal('300000.00'), 70, Decimal('210000.00'), datetime.date(2025, 1, 25), 115, 'medium-term'),
#  (13, 'Commonwealth Bank', 'Banking', 'Australia', 'New South Wales', 'New Business', 'Qualification', Decimal('350000.00'), 55, Decimal('192500.00'), datetime.date(2025, 2, 20), 141, 'medium-term'),
#  (2, 'PT Gojek', 'Transportation', 'Indonesia', 'Jakarta', 'Cross-sell', 'Proposal', Decimal('300000.00'), 60, Decimal('180000.00'), datetime.date(2025, 1, 15), 105, 'medium-term'),
#  (8, 'PT Blibli', 'E-commerce', 'Indonesia', 'West Java', 'Cross-sell', 'Proposal', Decimal('250000.00'), 65, Decimal('162500.00'), datetime.date(2025, 1, 20), 110, 'medium-term'),
#  (9, 'PT Lazada', 'E-commerce', 'Indonesia', 'East Java', 'New Business', 'Negotiation', Decimal('180000.00'), 85, Decimal('153000.00'), datetime.date(2024, 12, 25), 84, 'short-term'),
#  (19, 'Qantas Airways', 'Airlines', 'Australia', 'New South Wales', 'New Business', 'Negotiation', Decimal('180000.00'), 85, Decimal('153000.00'), datetime.date(2024, 12, 28), 87, 'short-term'),
#  (17, 'BHP Group', 'Mining', 'Australia', 'Western Australia', 'Upsell', 'Qualification', Decimal('250000.00'), 60, Decimal('150000.00'), datetime.date(2025, 2, 10), 131, 'medium-term'),
#  (18, 'Rio Tinto', 'Mining', 'Australia', 'Western Australia', 'Cross-sell', 'Proposal', Decimal('220000.00'), 65, Decimal('143000.00'), datetime.date(2025, 1, 15), 105, 'medium-term'),
#  (5, 'PT Traveloka', 'Travel', 'Indonesia', 'Jakarta', 'Cross-sell', 'Negotiation', Decimal('150000.00'), 75, Decimal('112500.00'), datetime.date(2024, 12, 20), 79, 'short-term'),
#  (3, 'PT Bukalapak', 'E-commerce', 'Indonesia', 'Jakarta', 'New Business', 'Qualification', Decimal('200000.00'), 40, Decimal('80000.00'), datetime.date(2025, 2, 1), 122, 'medium-term'),
#  (16, 'ANZ Bank', 'Banking', 'Australia', 'Victoria', 'New Business', 'Prospecting', Decimal('200000.00'), 40, Decimal('80000.00'), datetime.date(2025, 3, 10), 159, 'medium-term'),
#  (20, 'Virgin Australia', 'Airlines', 'Australia', 'New South Wales', 'Upsell', 'Prospecting', Decimal('150000.00'), 45, Decimal('67500.00'), datetime.date(2025, 3, 5), 154, 'medium-term'),
#  (10, 'PT JD.id', 'E-commerce', 'Indonesia', 'Jakarta', 'Upsell', 'Prospecting', Decimal('120000.00'), 35, Decimal('42000.00'), datetime.date(2025, 3, 15), 164, 'medium-term'),
#  (7, 'PT DANA', 'Fintech', 'Indonesia', 'Jakarta', 'Upsell', 'Qualification', Decimal('80000.00'), 50, Decimal('40000.00'), datetime.date(2025, 2, 15), 136, 'medium-term'),
#  (6, 'PT OVO', 'Fintech', 'Indonesia', 'Jakarta', 'New Business', 'Prospecting', Decimal('100000.00'), 30, Decimal('30000.00'), datetime.date(2025, 3, 1), 150, 'medium-term')]

# %% [markdown]
# **Key Findings:**
# - Total pipeline value: $4.5M with weighted value of $2.8M (62% probability)
# - Negotiation stage has highest weighted value - focus on closing these deals
# - Australia shows higher deal values but longer sales cycles
# - E-commerce and Banking sectors dominate high-value opportunities
# - 40% of pipeline is in immediate/short-term timeframe - revenue acceleration opportunity
#
# **Strategic Recommendations:**
# 1. SALES: Prioritize Negotiation stage deals with executive sponsorship
# 2. PROCESS: Implement stage-specific playbooks for each sales stage
# 3. FORECASTING: Use weighted pipeline value for more accurate revenue predictions
# 4. COACHING: Focus on improving win rates in Proposal and Negotiation stages

# %%
# %%sql
#
# ## Analysis 5: A/B Testing & Experiment Analysis
#
# select experiment_name,
#     experiment_type,
#     variant,
#     sample_size,
#     conversion_rate,
#     engagement_score,
#     revenue_impact,
#     statistical_significance,
#     case
#         when statistical_significance = 1 and conversion_rate > 0 then 'significant positive impact'
#         when statistical_significance = 1 and conversion_rate < 0 then 'significant negative impact'
#         when statistical_significance = 0 then 'not statistically significant'
#         else 'inconclusive'
#     end as result_intepretation,
#     case
#         when statistical_significance = 1 and conversion_rate > 0 then 'scale to 100%'
#         when statistical_significance = 1 and conversion_rate < 0 then 'discontinue'
#         when statistical_significance = 0 then 'run longer or increase sample size'
#         else 'invertigate further'
#     end as recommended_action
# from ab_test_experiments
# order by experiment_name, revenue_impact
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/google_ads_apac
#    mysql+pymysql://root:***@127.0.0.1:3306/myapp
# 12 rows affected.
# [('Display Ad Creative', 'UI/UX', 'Variant B', 15000, Decimal('0.0143'), Decimal('2.60'), Decimal('8000.00'), 0, 'not statistically significant', 'run longer or increase sample size'),
#  ('Display Ad Creative', 'UI/UX', 'Control', 15000, Decimal('0.0156'), Decimal('2.80'), Decimal('12000.00'), 0, 'not statistically significant', 'run longer or increase sample size'),
#  ('Display Ad Creative', 'UI/UX', 'Variant A', 15000, Decimal('0.0167'), Decimal('3.10'), Decimal('15000.00'), 0, 'not statistically significant', 'run longer or increase sample size'),
#  ('Search Ad Headlines', 'Messaging', 'Variant B', 10000, Decimal('0.0211'), Decimal('2.90'), Decimal('8000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('Search Ad Headlines', 'Messaging', 'Control', 10000, Decimal('0.0234'), Decimal('3.20'), Decimal('15000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('Search Ad Headlines', 'Messaging', 'Variant A', 10000, Decimal('0.0287'), Decimal('3.80'), Decimal('25000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('Shopping Ad Layout', 'UI/UX', 'Variant B', 12000, Decimal('0.0176'), Decimal('2.90'), Decimal('14000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('Shopping Ad Layout', 'UI/UX', 'Control', 12000, Decimal('0.0198'), Decimal('3.30'), Decimal('18000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('Shopping Ad Layout', 'UI/UX', 'Variant A', 12000, Decimal('0.0223'), Decimal('3.70'), Decimal('22000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('YouTube Ad Length', 'Product Feature', 'Variant A', 8000, Decimal('0.0289'), Decimal('3.70'), Decimal('16000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('YouTube Ad Length', 'Product Feature', 'Control', 8000, Decimal('0.0312'), Decimal('4.10'), Decimal('20000.00'), 1, 'significant positive impact', 'scale to 100%'),
#  ('YouTube Ad Length', 'Product Feature', 'Variant B', 8000, Decimal('0.0356'), Decimal('4.50'), Decimal('28000.00'), 1, 'significant positive impact', 'scale to 100%')]

# %% [markdown]
# **Key Findings:**
# - YouTube Ad Length experiment shows highest revenue impact (+$28K) - scale Variant B
# - Search Ad Headlines: Variant A significantly outperforms control (+$25K)
# - Display Ad Creative: No statistical significance - need larger sample size
# - Shopping Ad Layout: Variant A shows promise but needs validation
# - Overall: 50% of experiments show statistical significance - good experimentation culture
#
# **Strategic Recommendations:**
# 1. PRODUCT: Immediately scale YouTube Ad Length Variant B to 100% of traffic
# 2. MARKETING: Roll out Search Ad Headlines Variant A across all campaigns
# 3. EXPERIMENTATION: Increase sample sizes for Display and Shopping experiments
# 4. PROCESS: Implement faster decision-making for statistically significant results

# %%
# %%sql
#
# #Executive Summary and Strategic Insight
#
# with kpi_summary as(
#     select
#         count(distinct c.customer_id) tot_cust,
#         count(distinct m.market_id) tot_markets,
#         sum(c.total_ad_spend) tot_revenue,
#         avg(c.lifetime_value) avg_cust_lifetime,
#         count(distinct so.opportunity_id) total_opportunities,
#         sum(so.estimated_value * so.probability_percent/100) weighted_pipeline_value,
#         avg(cpa.adoption_score) avg_product_adoption_score
#     from customers c
#     cross join markets m
#     left join sales_opportunities so on c.customer_id = so.customer_id
#     left join customer_product_adoption cpa on cpa.customer_id = c.customer_id
# )
#
# select 'Total Customer' as metric,
#     tot_cust as value,
#     'Active customers across all markets' as description
# from kpi_summary
# union all
# select
#     'Total Revenue' as metric,
#     round(avg_cust_lifetime,2) as value,
#     'Weighted sales pipeline value' as description
# from kpi_summary
# union all
# select
#     'Avg. Product Adoption' as metric,
#     round(avg_product_adoption_score,2) as value,
#     'Average product adoption score' as description
# from kpi_summary
# Out:
#  * mysql+pymysql://root:***@127.0.0.1:3306/google_ads_apac
#    mysql+pymysql://root:***@127.0.0.1:3306/myapp
# 3 rows affected.
# [('Total Customer', Decimal('20.00'), 'Active customers across all markets'),
#  ('Total Revenue', Decimal('3309375.00'), 'Weighted sales pipeline value'),
#  ('Avg. Product Adoption', Decimal('4.32'), 'Average product adoption score')]

# %% [markdown]
# ### Growth Strategy
# - **IMMEDIATE (0-3 months):** Launch expansion in Papua and Maluku with local partnerships
# - **SHORT-TERM (3-6 months):** Scale successful A/B test variants (YouTube Ad Length, Search Headlines)
# - **MEDIUM-TERM (6-12 months):** Develop premium tier for Australian markets
# - **LONG-TERM (12+ months):** Create market-specific product bundles
#
# ### Revenue Optimization
# - Focus on $2.8M weighted pipeline value with 62% probability
# - Prioritize Negotiation stage deals (Woolworths, Tokopedia, Coles)
# - Implement win-back campaigns for At Risk customers ($30M+ in lifetime value)
# - Scale proven A/B test results for $201K additional revenue impact
#
# ### Customer Success
# - Assign dedicated account managers to Champions segment (Woolworths, Coles, Commonwealth Bank)
# - Create structured onboarding for New Customers (PT Tokopedia, PT Gojek)
# - Develop industry-specific bundles for Loyal Customers
# - Implement customer health scoring based on RFM analysis
#
# ### Product Strategy
# - **Search Ads:** Maintain market leadership (100% adoption)
# - **YouTube Ads:** Launch education program for Indonesian markets (71% adoption gap)
# - **Display Ads:** Improve targeting and case studies (50-60% adoption)
# - **Shopping Ads:** Partner with e-commerce platforms for market expansion
#
# ### Operational Excellence
# - Implement stage-specific sales playbooks for pipeline optimization
# - Create faster decision-making process for A/B test results
# - Establish market penetration tracking dashboard
# - Develop customer segmentation automation based on RFM scores
#
# ---
#
# ## Portfolio Impact
#
# This analysis demonstrates advanced SQL skills including:
# - Complex CTEs and window functions for market penetration analysis
# - Advanced customer segmentation using RFM methodology
# - Statistical analysis of A/B testing results
# - Revenue forecasting with probability-weighted pipeline analysis
# - Strategic business recommendations based on data insights
#
# **Key SQL Techniques Used:**
# - Common Table Expressions (CTEs)
# - Window Functions
# - Advanced CASE Statements
# - Multi-table JOINs
# - Statistical Analysis Functions
# - Date and Time Functions
# - Aggregation and Grouping
# - Subqueries and Derived Tables
#
# **Business Impact:**
# - Identified $2.2B+ revenue opportunity in underpenetrated markets
# - $201K+ revenue opportunity through product adoption improvements
# - $30M+ lifetime value at risk requiring win-back campaigns
# - Clear revenue forecasting with $2.8M weighted pipeline value
# - $201K additional revenue through scaling successful A/B test variants
